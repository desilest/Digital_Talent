# %% [markdown]
# # Desi Lestari
# ## Big Data Kelas C

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %%
run("SHOW TABLES")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %% [markdown]
# <img src="http://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png" />

# %% [markdown]
# # One to many relationship

# %% [markdown]
# ## 1. Report the account representative for each customer.

# %%
run("""
SELECT 
    customerName,
    CONCAT(firstName,' ',lastName) AS employeeName
FROM
    customers
        INNER JOIN
    employees ON salesRepEmployeeNumber = employeeNumber
""")
# Out:
#                           customerName     employeeName
# 0         Mini Gifts Distributors Ltd.  Leslie Jennings
# 1                      Mini Wheels Co.  Leslie Jennings
# 2                 Technics Stores Inc.  Leslie Jennings
# 3             Corporate Gift Ideas Co.  Leslie Jennings
# 4            The Sharp Gifts Warehouse  Leslie Jennings
# 5             Signal Collectibles Ltd.  Leslie Jennings
# 6                   Signal Gift Stores  Leslie Thompson
# 7                    Toys4GrownUps.com  Leslie Thompson
# 8                    Boards & Toys Co.  Leslie Thompson
# 9         Collectable Mini Designs Co.  Leslie Thompson
# 10          Men 'R' US Retailers, Ltd.  Leslie Thompson
# 11         West Coast Collectables Co.  Leslie Thompson
# 12          Cambridge Collectables Co.   Julie Firrelli
# 13            Online Mini Collectables   Julie Firrelli
# 14                 Mini Creations Ltd.   Julie Firrelli
# 15             Classic Gift Ideas, Inc   Julie Firrelli
# ...

# %% [markdown]
# # 2. Report total payments for Atelier graphique.

# %%
run("""SELECT FORMAT(SUM(amount),2) AS Total
FROM payments 
    JOIN
    customers USING (customerNumber)
    WHERE customerName = 'Atelier graphique'
""")
# Out:
#        Total
# 0  22,314.36

# %% [markdown]
# # 3. Report the total payments by date

# %%
run("""SELECT paymentDate, FORMAT(SUM(amount),2) AS Total_Payment
    FROM payments
    GROUP BY paymentDate
""")
# Out:
#     paymentDate Total_Payment
# 0    2003-01-16     10,223.83
# 1    2003-01-28     10,549.01
# 2    2003-01-30      5,494.78
# 3    2003-02-16     50,218.95
# 4    2003-02-20     53,959.21
# 5    2003-02-25     40,206.20
# 6    2003-03-02     52,151.81
# 7    2003-03-09     51,001.22
# 8    2003-03-12     22,292.62
# 9    2003-03-20     25,833.14
# 10   2003-03-27     48,425.69
# 11   2003-04-09     24,212.79
# 12   2003-04-11     11,044.30
# 13   2003-04-16     21,665.98
# 14   2003-04-19      1,627.56
# 15   2003-04-20     33,383.14
# 16   2003-04-22     44,380.15
# 17   2003-05-09      3,101.40
# 18   2003-05-12     35,826.33
# 19   2003-05-20     45,864.03
# 20   2003-05-21     16,700.47
# 21   2003-05-25     50,824.66
# 22   2003-05-31      7,565.08
# 23   2003-06-05     14,571.44
# 24   2003-06-06     32,641.98
# 25   2003-06-13     57,131.92
# 26   2003-06-18     58,841.35
# 27   2003-06-25     17,032.29
# 28   2003-07-05      2,880.00
# 29   2003-07-06      6,036.96
# ...

# %% [markdown]
# ## 4.	Report the products that have not been sold.

# %%
run("""
    SELECT productCode, productName 
    FROM products 
        LEFT JOIN orderdetails 
    USING (productCode) 
    WHERE orderNumber is NULL
""")
# Out:
#   productCode        productName
# 0    S18_3233  1985 Toyota Supra

# %% [markdown]
# ## 5.	List the amount paid by each customer.

# %%
run("""
SELECT customerNumber, customerName, FORMAT(SUM(amount),2) AS Total_Pembelian 
    FROM customers 
JOIN payments 
    USING(customerNumber) 
GROUP BY customerNumber
""")
# Out:
#     customerNumber                        customerName Total_Pembelian
# 0              103                   Atelier graphique       22,314.36
# 1              112                  Signal Gift Stores       80,180.98
# 2              114          Australian Collectors, Co.      180,585.07
# 3              119                   La Rochelle Gifts      116,949.68
# 4              121                  Baane Mini Imports      104,224.79
# 5              124        Mini Gifts Distributors Ltd.      584,188.24
# 6              128                Blauer See Auto, Co.       75,937.76
# 7              129                     Mini Wheels Co.       66,710.56
# 8              131                   Land of Toys Inc.      107,639.94
# 9              141              Euro+ Shopping Channel      715,738.98
# 10             144            Volvo Model Replicas, Co       43,680.65
# 11             145            Danish Wholesale Imports      107,446.50
# ...

# %% [markdown]
# ## 6.	How many orders have been placed by Herkku Gifts?

# %%
run ("""
SELECT customerName AS Name, COUNT(orderNumber) AS Total
    FROM orders
JOIN customers USING (customerNumber)
WHERE customerName = 'Herkku Gifts'
""")
# Out:
#            Name  Total
# 0  Herkku Gifts      3

# %% [markdown]
# ## 7.	Who are the employees in Boston?

# %%
run("""
SELECT CONCAT(firstName,' ',lastName) AS Employee_Name
    FROM employees
JOIN offices USING (officeCode)
    WHERE city = 'Boston'
""")
# Out:
#      Employee_Name
# 0   Julie Firrelli
# 1  Steve Patterson

# %% [markdown]
# ## 8.	Report those payments greater than $100,000. Sort the report so the customer who made the highest payment appears first

# %%
run("""
SELECT customerNUmber, customerName, FORMAT(amount,2) AS payment 
    FROM payments 
JOIN customers 
    USING (customerNumber)
WHERE amount>100000
    ORDER BY amount DESC
""")
# Out:
#    customerNUmber                  customerName     payment
# 0             141        Euro+ Shopping Channel  120,166.58
# 1             141        Euro+ Shopping Channel  116,208.40
# 2             124  Mini Gifts Distributors Ltd.  111,654.40
# 3             148       Dragon Souveniers, Ltd.  105,743.00
# 4             124  Mini Gifts Distributors Ltd.  101,244.59

# %% [markdown]
# ## 9.	List the value of 'On Hold' orders.

# %%
run("""
SELECT FORMAT(SUM(quantityOrdered*priceEach),2) AS Value
    FROM orderdetails
JOIN orders 
    USING (orderNumber)
WHERE status='On Hold'
""")
# Out:
#         Value
# 0  169,575.61

# %% [markdown]
# ## 10.	Report the number of orders 'On Hold' for each customer.

# %%
run("""
SELECT COUNT(customerNumber) AS total, customerName, status
    FROM customers
JOIN orders USING (customerNumber)
    WHERE status='On Hold'
GROUP BY customerNumber
""")
# Out:
#    total               customerName   status
# 0      1   Volvo Model Replicas, Co  On Hold
# 1      1    Tekni Collectables Inc.  On Hold
# 2      1          Gifts4AllAges.com  On Hold
# 3      1  The Sharp Gifts Warehouse  On Hold

# %% [markdown]
# # Many to many relationship

# %% [markdown]
# ## 1.	List products sold by order date.

# %%
run("""
SELECT orderDate, productName
    FROM products
JOIN orderdetails USING (productCode)
    JOIN orders USING (orderNumber)
ORDER BY orderDate
""")
# Out:
#        orderDate                                  productName
# 0     2003-01-06          1932 Alfa Romeo 8C2300 Spider Sport
# 1     2003-01-06                           1911 Ford Town Car
# 2     2003-01-06             1936 Mercedes Benz 500k Roadster
# 3     2003-01-06                     1917 Grand Touring Sedan
# 4     2003-01-09    1938 Cadillac V-16 Presidential Limousine
# 5     2003-01-09                    1932 Model A Ford J-Coupe
# 6     2003-01-09                  1939 Chevrolet Deluxe Coupe
# 7     2003-01-09                       1928 Mercedes-Benz SSK
# 8     2003-01-10                         1937 Lincoln Berline
# 9     2003-01-10     1936 Mercedes-Benz 500K Special Roadster
# 10    2003-01-29                              1982 Camaro Z28
# 11    2003-01-29                               1958 Setra Bus
# 12    2003-01-29                       1940 Ford Pickup Truck
# 13    2003-01-29                        1936 Chrysler Airflow
# ...

# %% [markdown]
# ## 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.

# %%
run("""
SELECT productName, orderNumber, orderDate 
    FROM products
JOIN orderdetails USING (productCode)
    JOIN orders USING (orderNumber)
WHERE productName='1940 Ford Pickup Truck'
ORDER BY orderDate DESC
""")
# Out:
#                productName  orderNumber   orderDate
# 0   1940 Ford Pickup Truck        10424  2005-05-31
# 1   1940 Ford Pickup Truck        10411  2005-05-01
# 2   1940 Ford Pickup Truck        10391  2005-03-09
# 3   1940 Ford Pickup Truck        10381  2005-02-17
# 4   1940 Ford Pickup Truck        10370  2005-01-20
# 5   1940 Ford Pickup Truck        10357  2004-12-10
# 6   1940 Ford Pickup Truck        10347  2004-11-29
# 7   1940 Ford Pickup Truck        10333  2004-11-18
# 8   1940 Ford Pickup Truck        10322  2004-11-04
# 9   1940 Ford Pickup Truck        10312  2004-10-21
# 10  1940 Ford Pickup Truck        10304  2004-10-11
# 11  1940 Ford Pickup Truck        10291  2004-09-08
# 12  1940 Ford Pickup Truck        10280  2004-08-17
# 13  1940 Ford Pickup Truck        10270  2004-07-19
# 14  1940 Ford Pickup Truck        10258  2004-06-15
# 15  1940 Ford Pickup Truck        10245  2004-05-04
# 16  1940 Ford Pickup Truck        10228  2004-03-10
# ...

# %% [markdown]
# ## 3.	List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?

# %%
run("""
SELECT orderNumber, customerName, FORMAT(SUM(priceEach*quantityOrdered),2) AS Value
    FROM customers
JOIN orders USING (customerNumber)
    JOIN orderdetails USING (orderNumber)
GROUP BY orderNumber
HAVING SUM(priceEach*quantityOrdered)>25000
""")
# Out:
#      orderNumber                  customerName      Value
# 0          10103            Baane Mini Imports  50,218.95
# 1          10104        Euro+ Shopping Channel  40,206.20
# 2          10105      Danish Wholesale Imports  53,959.21
# 3          10106                 Rovelli Gifts  52,151.81
# 4          10108               Cruz & Sons Co.  51,001.22
# 5          10109  Motor Mint Distributors Inc.  25,833.14
# 6          10110                AV Stores, Co.  48,425.69
# 7          10114     La Corne D'abondance, Co.  33,383.14
# 8          10117       Dragon Souveniers, Ltd.  44,380.15
# 9          10119         Salzburg Collectables  35,826.33
# 10         10120    Australian Collectors, Co.  45,864.03
# 11         10122          Marseille Mini Autos  50,824.66
# 12         10124            Signal Gift Stores  32,641.98
# 13         10126    Corrida Auto Replicas, Ltd  57,131.92
# 14         10127            Muscle Machine Inc  58,841.35
# ...

# %% [markdown]
# ## 4.	Are there any products that appear on all orders?

# %%
run("""
SELECT productCode, COUNT(*) as Amount
FROM orderdetails
GROUP BY productCode
HAVING Amount=
(SELECT COUNT(*) FROM orders)
""")
# Out:
# Empty DataFrame
# Columns: [productCode, Amount]
# Index: []

# %% [markdown]
# ## 5.	List the names of products sold at less than 80% of the MSRP.

# %%
run("""
SELECT DISTINCT productName, productCode, MSRP, priceEach, (0.8*MSRP)
    FROM products JOIN orderdetails USING (productCode)
    JOIN orders USING (orderNumber)
WHERE priceEach < (0.8*MSRP)
ORDER BY productCode
""")
# Out:
#                                     productName productCode    MSRP  \
# 0                         1996 Moto Guzzi 1100i    S10_2016  118.94
# 1                               1993 Mazda RX-7    S18_1129  141.54
# 2                          1937 Lincoln Berline    S18_1342  102.74
# 3                         1965 Aston Martin DB5    S18_1589  124.44
# 4                   1980s Black Hawk Helicopter    S18_1662  157.69
# 5                            1911 Ford Town Car    S18_2248   60.54
# 6                                P-51-D Mustang    S18_2581   84.48
# 7                   1992 Ferrari 360 Spider red    S18_3232  169.34
# 8                      Collectable Wooden Train    S18_3259  100.84
# 9                         1976 Ford Gran Torino    S18_3482  146.99
# 10          1932 Alfa Romeo 8C2300 Spider Sport    S18_4409   92.03
# 11                             1940s Ford truck    S18_4600  121.08
# 12                  1939 Chevrolet Deluxe Coupe    S24_1937   33.19
# ...

# %% [markdown]
# ## 6.	Reports those products that have been sold with a markup of 100% or more (i.e., the priceEach is at least twice the buyPrice)

# %%
run("""
SELECT productCode, productName, priceEach, buyPrice, priceEach-buyPrice AS Markup
    FROM products JOIN orderdetails USING (productCode)
WHERE priceEach > (2*buyPrice)
ORDER BY productCode
""")
# Out:
#     productCode                           productName  priceEach  buyPrice  \
# 0      S10_1949              1952 Alpine Renault 1300     214.30     98.58
# 1      S10_1949              1952 Alpine Renault 1300     205.73     98.58
# 2      S10_1949              1952 Alpine Renault 1300     212.16     98.58
# 3      S10_1949              1952 Alpine Renault 1300     207.87     98.58
# 4      S10_1949              1952 Alpine Renault 1300     203.59     98.58
# 5      S10_1949              1952 Alpine Renault 1300     203.59     98.58
# 6      S10_1949              1952 Alpine Renault 1300     205.73     98.58
# 7      S10_1949              1952 Alpine Renault 1300     214.30     98.58
# 8      S10_1949              1952 Alpine Renault 1300     205.73     98.58
# 9      S10_1949              1952 Alpine Renault 1300     210.01     98.58
# 10     S10_1949              1952 Alpine Renault 1300     201.44     98.58
# ...

# %% [markdown]
# ## 7.	List the products ordered on a Monday.

# %%
run("""
SELECT DAYNAME(orderDate) AS Day, productName
    FROM products JOIN orderdetails USING (productCode)
    JOIN orders USING (orderNumber)
WHERE DAYOFWEEK(orderDate)=2
ORDER BY productCode
""")
# Out:
#         Day                            productName
# 0    Monday  1969 Harley Davidson Ultimate Chopper
# 1    Monday  1969 Harley Davidson Ultimate Chopper
# 2    Monday  1969 Harley Davidson Ultimate Chopper
# 3    Monday  1969 Harley Davidson Ultimate Chopper
# 4    Monday  1969 Harley Davidson Ultimate Chopper
# 5    Monday  1969 Harley Davidson Ultimate Chopper
# 6    Monday               1952 Alpine Renault 1300
# 7    Monday               1952 Alpine Renault 1300
# 8    Monday               1952 Alpine Renault 1300
# 9    Monday               1952 Alpine Renault 1300
# 10   Monday               1952 Alpine Renault 1300
# 11   Monday                  1996 Moto Guzzi 1100i
# 12   Monday                  1996 Moto Guzzi 1100i
# 13   Monday                  1996 Moto Guzzi 1100i
# 14   Monday                  1996 Moto Guzzi 1100i
# 15   Monday                  1996 Moto Guzzi 1100i
# 16   Monday                  1996 Moto Guzzi 1100i
# ...

# %% [markdown]
# ## 8.	What is the quantity on hand for products listed on 'On Hold' orders?

# %%
run("""
SELECT orderNumber, productCode, status, quantityOrdered
FROM orderdetails JOIN orders USING (orderNumber)
WHERE status='On Hold'
""")
# Out:
#     orderNumber productCode   status  quantityOrdered
# 0         10334    S10_4962  On Hold               26
# 1         10334    S18_2319  On Hold               46
# 2         10334    S18_2432  On Hold               34
# 3         10334    S18_3232  On Hold               20
# 4         10334    S18_4600  On Hold               49
# 5         10334    S24_2300  On Hold               42
# 6         10401    S18_2581  On Hold               42
# 7         10401    S24_1785  On Hold               38
# 8         10401    S24_3949  On Hold               64
# 9         10401    S24_4278  On Hold               52
# 10        10401    S32_1374  On Hold               49
# 11        10401    S32_4289  On Hold               62
# 12        10401    S50_1341  On Hold               56
# 13        10401   S700_1691  On Hold               11
# 14        10401   S700_2466  On Hold               85
# 15        10401   S700_2834  On Hold               21
# ...

# %%
run("""
SELECT FORMAT(SUM(quantityOrdered),0) AS Total, status
FROM orderdetails JOIN orders USING (orderNumber)
WHERE status='On Hold'
""")
# Out:
#    Total   status
# 0  1,994  On Hold

# %% [markdown]
# # THANK YOU :)
